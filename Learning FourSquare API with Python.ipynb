# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'KQXAZLPXTBLGPUSPYO2ZKUBGBZW42CY0OEARVSQ4H3CFQH2V' # your Foursquare ID
CLIENT_SECRET = '4JY5XCY4EU0AOAP4DRSWA2VZUYK3IZ4SLNLM1WYJWGPGTGOO' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KQXAZLPXTBLGPUSPYO2ZKUBGBZW42CY0OEARVSQ4H3CFQH2V
# CLIENT_SECRET:4JY5XCY4EU0AOAP4DRSWA2VZUYK3IZ4SLNLM1WYJWGPGTGOO

# %%
address = '100 Harbour Parade, Southampton, UK'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 50.9053776 -1.4094438

# %%
search_query = 'Hotel'
radius = 1200
print(search_query + ' .... OK!')
# Out:
# Hotel .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KQXAZLPXTBLGPUSPYO2ZKUBGBZW42CY0OEARVSQ4H3CFQH2V&client_secret=4JY5XCY4EU0AOAP4DRSWA2VZUYK3IZ4SLNLM1WYJWGPGTGOO&ll=50.9053776,-1.4094438&v=20180604&query=Hotel&radius=1200&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fa854222be1a37c28075e08'},
#  'response': {'venues': [{'id': '4b5b45daf964a52051f028e3',
#     'name': 'Grand Harbour Hotel',
#     'location': {'address': '5 West Quay Rd',
#      'lat': 50.8994760498551,
#      'lng': -1.4077499392861765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.8994760498551,
#        'lng': -1.4077499392861765}],
#      'distance': 667,
#      'postalCode': 'SO15 1AG',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5 West Quay Rd',
#       'Southampton',
#       'Hampshire',
#       'SO15 1AG',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-246-5acf500bf9ad>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                                              name  \
# 0  4b5b45daf964a52051f028e3  Grand Harbour Hotel
# 1  4bfeb08f369476b09ab08c1f  Mercure Dolphin Hotel
# 2  5a70679360d11b2a4cb918b3  Premier Inn Southampton (Cumberland Place) hotel
# 3  4be18cfd8dd062b580533e3c  Rosida Garden Hotel
# 4  4bcf67590ffdce720f70b2c0  The Star Hotel
#
#                                                                                                                                                                                                            categories  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                 name       categories  \
# 0   Grand Harbour Hotel                               Hotel
# 1   Mercure Dolphin Hotel                             Hotel
# 2   Premier Inn Southampton (Cumberland Place) hotel  Hotel
# 3   Rosida Garden Hotel                               Hotel
# 4   The Star Hotel                                    Hotel
# 5   The London Hotel                                  Gay Bar
# 6   The Winston Hotel                                 Hotel
# 7   Blue Keys Hotel                                   Bed & Breakfast
# 8   Hotel SC                                          Police Station
# 9   Hotel Chocolat                                    Chocolate Shop
# 10  The Hotel Resurant                                Restaurant
# 11  The Hotel Bar                                     Hotel Bar
# 12  Hotel Bar                                         Hotel Bar
# 13  Hotel Restaurant                                  Breakfast Spot
# ...

# %%
dataframe_filtered.name
# Out:
# 0     Grand Harbour Hotel
# 1     Mercure Dolphin Hotel
# 2     Premier Inn Southampton (Cumberland Place) hotel
# 3     Rosida Garden Hotel
# 4     The Star Hotel
# 5     The London Hotel
# 6     The Winston Hotel
# 7     Blue Keys Hotel
# 8     Hotel SC
# 9     Hotel Chocolat
# 10    The Hotel Resurant
# 11    The Hotel Bar
# 12    Hotel Bar
# 13    Hotel Restaurant
# 14    Ennio's Boutique Hotel
# 15    Craigdarroch Arms Hotel
# 16    Buccleuch & Queensberry Hotel
# 17    Star Hotel Bar
# 18    The Majesty Hotel
# 19    Mayfair Hotel
# 20    Antico Hotel
# 21    Banister House Hotel
# 22    Addenro House Hotel
# 23    Novotel
# 24    Ibis Budget
# 25    Premier Inn Southampton West Quay
# 26    Holiday Inn Southampton
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Szentkirályi utca 6.
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Carnival House',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Coffee places as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4bd5beef9649ce72219b511d' # ID of EarlyBird Coffee
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4bd5beef9649ce72219b511d?client_id=KQXAZLPXTBLGPUSPYO2ZKUBGBZW42CY0OEARVSQ4H3CFQH2V&client_secret=4JY5XCY4EU0AOAP4DRSWA2VZUYK3IZ4SLNLM1WYJWGPGTGOO&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4bd5beef9649ce72219b511d',
#  'name': 'Novotel',
#  'contact': {'phone': '+442381072800', 'formattedPhone': '+44 23 8107 2800'},
#  'location': {'address': '1 West Quay Road',
#   'lat': 50.90560686949242,
#   'lng': -1.4152500425814196,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 50.90560686949242,
#     'lng': -1.4152500425814196}],
#   'postalCode': 'SO15 1RA',
#   'cc': 'GB',
#   'city': 'Southampton',
#   'state': 'Hampshire',
#   'country': 'United Kingdom',
#   'formattedAddress': ['1 West Quay Road',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.7

# %%
result['response']['venue']['tips']['count']
# Out:
# 13

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fa854a34ec80a3f051e9892'},
#  'response': {'tips': {'count': 13,
#    'items': [{'id': '5b536ce6c21cb1002c200405',
#      'createdAt': 1532194022,
#      'text': 'I liked both the room and the breakfast. Close to the harbour and ferries to Isle of Wight. Also close to the West Quay shopping centre and the train station.',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5b536ce6c21cb1002c200405',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '4873243',
#       'isSanctioned': False,
#       'firstName': 'Sverker',
#       'lastName': 'B',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/YSKREJR0UUWHDOLH.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered.reindex()
# Out:
# <ipython-input-264-252e55242536>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# <ipython-input-264-252e55242536>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   tips_df = json_normalize(tips) # json normalize tips
#                                                                                                                                                              text  \
# 0  I liked both the room and the breakfast. Close to the harbour and ferries to Isle of Wight. Also close to the West Quay shopping centre and the train station.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              5b536ce6c21cb1002c200405  Sverker
#
#   user.lastName  user.id
# 0  B             4873243

# %%
idnumber = '487324' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}'.format(idnumber, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
#user_data = results['response']['user']
user_data=results['response']['tips']['items'][0]['venue']['photos']['groups'][0]['items']#['items']
# display features associated with user
#user_data.keys()
#results
pd.set_option('display.max_colwidth', -1)

users_df = json_normalize(user_data)

# filter columns
filtered_columns = ['id','user.id','user.firstName','user.lastName']
tips_filtered = users_df.loc[:, filtered_columns]

# display user's tips
df=tips_filtered
df
#url
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-272-b00cf3d68ed1> in <module>
#       6 results = requests.get(url).json()
#       7 #user_data = results['response']['user']
# ----> 8 user_data=results['response']['tips']['items'][0]['venue']['photos']['groups'][0]['items']#['items']
#       9 # display features associated with user
#      10 #user_data.keys()
#
# IndexError: list index out of range

# %%
g=df.loc[df['user.id'] == '4873243	']
print('First Name: ' + g['user.firstName'])
print('Last Name: ' + g['user.lastName'])
# Out:
# Series([], Name: user.firstName, dtype: object)
# Series([], Name: user.lastName, dtype: object)

# %%
# 1. grab prefix of photo
# 2. grab suffix of photo
# 3. concatenate them using the image size  
Image(url='https://fastly.4sqi.net/img/general/540x920/27341902_ODR5Au05ENkSyu3xxfV3VOfCa0idDfm9Q4n8YbhZDRQ.jpg')
# Out:
# <img src="https://fastly.4sqi.net/img/general/540x920/27341902_ODR5Au05ENkSyu3xxfV3VOfCa0idDfm9Q4n8YbhZDRQ.jpg"/>

# %%
# define tips URL
user_id='484542633'
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
# <ipython-input-271-bd61904bb9ce>:10: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# <ipython-input-271-bd61904bb9ce>:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   tips_df = json_normalize(tips)
#                                                                                                                                   text  \
# 0   They serve coffee!!!!!!
# 1   Quick, cheap lunch that tastes good! Way shorter line than Chipotle, too.
# 2   You’re not a real New Yorker until you’ve shame-ordered Insomnia Cookies for delivery at 3am
# 3   Good for you yet still tasty! Clean green protein is my go-to after I hit the gym 💪
# 4   Burger game strong 💪
# ...
